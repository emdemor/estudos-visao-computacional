# %%
from quantization import gray_quantization
from PIL import Image, ImageOps
import numpy as np

# %% [markdown]
# ### Importação da Imagem

# %%
# Carrega a imagem
image = Image.open("images/tucano.png")

# Converte em escala de cinza
gray_image = ImageOps.grayscale(image)

# Converte em um array de numpy
gray_image_array = np.asarray(gray_image)

gray_image
# Out:
# <PIL.Image.Image image mode=L size=670x479 at 0x7FC18E3CFDA0>

# %% [markdown]
# ### Quantização

# %%
# Define a quantidade de bits
b = 1

# Aplica a quantização
quant_image_array = gray_quantization(gray_image_array, b)

# Converte em um objeto PIL.Image.Image
quant_image = Image.fromarray(quant_image_array)

quant_image
# Out:
# <PIL.Image.Image image mode=L size=670x479 at 0x7FC18E3CFDD8>
